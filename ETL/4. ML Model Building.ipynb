# %% [markdown]
# # Now - Machine Learning.
# ### The data that we processed earlier related to orders and sales numbers. Another important aspect of an organization's business is **customer churn**.
#
# ### For this module, we will build a machine learning model to predict which customers are likely to churn.
#
#
# # We will be using Databricks AutoML to build a baseline ML model
#
# * This section will be done in the 'Machine Learning' tab
# * We will kickstart Auto-ML first and while it is running, I will explain what Auto-ML does
# * This exercise will be mostly done on the Auto-ML screen

# %% [markdown]
# ### Set timeout settings in Auto-ML to be 5 mins
# * "Advanced configuration" -> "Stopping Conditions" -> "Timeout (minutes)" -> 5 mins

# %% [markdown]
# # Let's talk about Auto-ML while it is doing training
# <br>
#
# <img src="https://github.com/deedeeck/databricks_assets/blob/main/pics/automl1.jpg?raw=true"/>
# <br>

# %% [markdown]
# <img src="https://github.com/deedeeck/databricks_assets/blob/main/pics/automl2.jpg?raw=true"/>

# %% [markdown]
# <img src="https://github.com/deedeeck/databricks_assets/blob/main/pics/automl3.jpg?raw=true"/>

# %% [markdown]
# <img src="https://github.com/deedeeck/databricks_assets/blob/main/pics/automl4.jpg?raw=true"/>

# %% [markdown]
# <img src="https://github.com/deedeeck/databricks_assets/blob/main/pics/automl5.jpg?raw=true"/>
